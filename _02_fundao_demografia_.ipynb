# %%
# %matplotlib inline
import matplotlib
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### 1. Dados - Receitas, cadastro e bens dos candidatos

# %%
df_receitas = pd.read_csv('../dados_tse/2020/receitas_candidatos_2020_BRASIL.csv', sep = ';', encoding = 'latin1')
df_cadastro = pd.read_csv('../dados_tse/2020/consulta_cand_2020_BRASIL.csv', sep = ';', encoding = 'latin1')
df_bens = pd.read_csv('../dados_tse/2020/bem_candidato_2020_BRASIL.csv', sep = ';', encoding = 'latin1')

# %%
df_receitas.sample(3)
# Out:
#         DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO NM_TIPO_ELEICAO  \
# 325086  06/11/2020   22:14:51         2020                2       Ordinária
# 471857  06/11/2020   22:14:51         2020                2       Ordinária
# 593074  06/11/2020   22:14:51         2020                2       Ordinária
#
#         CD_ELEICAO                DS_ELEICAO  DT_ELEICAO  ST_TURNO  \
# 325086         426  Eleições Municipais 2020  15/11/2020         1
# 471857         426  Eleições Municipais 2020  15/11/2020         1
# 593074         426  Eleições Municipais 2020  15/11/2020         1
#
#          TP_PRESTACAO_CONTAS     ...     DS_CARGO_CANDIDATO_DOADOR  \
# 325086               Parcial     ...                      Prefeito
# 471857               Parcial     ...                      Prefeito
# 593074  Relatório Financeiro     ...                        #NULO#
#
#         NR_PARTIDO_DOADOR SG_PARTIDO_DOADOR  \
# 325086                 45              PSDB
# 471857                 55               PSD
# 593074                 -1            #NULO#
#
#                               NM_PARTIDO_DOADOR       NR_RECIBO_DOACAO  \
# 325086  Partido da Social Democracia Brasileira                 #NULO#
# 471857               Partido Social Democrático  772341342730MG000001E
# 593074                                   #NULO#  143001348631MG000003E
#
#         NR_DOCUMENTO_DOACAO  SQ_RECEITA  DT_RECEITA  \
# 325086               #NULO#    13752130  20/10/2020
# 471857               #NULO#    13187182  02/10/2020
# 593074               #NULO#    14187409  15/10/2020
#
#                                                DS_RECEITA  VR_RECEITA
# 325086  DOAÇÃO CANDIDATO FRADIQUE DE ADESIVOS BOTON 6·...      195,00
# 471857        ASSESSORIA E CONSULTORIA CONTABIL ELEITORAL      300,00
# 593074                            SERVICOS DE PANFLETISTA      522,50
#
# [3 rows x 57 columns]

# %%
df_cadastro.sample(3)
# Out:
#         DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO  \
# 318324  07/11/2020   12:07:41         2020                2
# 492925  07/11/2020   12:07:41         2020                2
# 515971  07/11/2020   12:07:41         2020                2
#
#           NM_TIPO_ELEICAO  NR_TURNO  CD_ELEICAO                DS_ELEICAO  \
# 318324  ELEIÇÃO ORDINÁRIA         1         426  Eleições Municipais 2020
# 492925  ELEIÇÃO ORDINÁRIA         1         426  Eleições Municipais 2020
# 515971  ELEIÇÃO ORDINÁRIA         1         426  Eleições Municipais 2020
#
#         DT_ELEICAO TP_ABRANGENCIA            ...             DS_SIT_TOT_TURNO  \
# 318324  15/11/2020      MUNICIPAL            ...                       #NULO#
# 492925  15/11/2020      MUNICIPAL            ...                       #NULO#
# 515971  15/11/2020      MUNICIPAL            ...                       #NULO#
#
#         ST_REELEICAO ST_DECLARAR_BENS  NR_PROTOCOLO_CANDIDATURA  \
# 318324             N                N                        -1
# 492925             N                S                        -1
# 515971             N                S                        -1
#
#                 NR_PROCESSO  CD_SITUACAO_CANDIDATO_PLEITO  \
# 318324  6002373220206090096                            -1
# 492925  6001912420206160007                            -1
# 515971  6002472720206130044                            -1
#
#         DS_SITUACAO_CANDIDATO_PLEITO CD_SITUACAO_CANDIDATO_URNA  \
# 318324                        #NULO#                         -1
# 492925                        #NULO#                         -1
# 515971                        #NULO#                         -1
#
#        DS_SITUACAO_CANDIDATO_URNA ST_CANDIDATO_INSERIDO_URNA
# 318324                     #NULO#                        SIM
# 492925                     #NULO#                        SIM
# 515971                     #NULO#                        NÃO
#
# [3 rows x 63 columns]

# %%
df_bens.sample(3)
# Out:
#         DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO  \
# 92721   07/11/2020   12:07:11         2020                2
# 810971  07/11/2020   12:07:11         2020                2
# 181320  07/11/2020   12:07:11         2020                2
#
#           NM_TIPO_ELEICAO  CD_ELEICAO                DS_ELEICAO  DT_ELEICAO  \
# 92721   Eleição Ordinária         426  Eleições Municipais 2020  15/11/2020
# 810971  Eleição Ordinária         426  Eleições Municipais 2020  15/11/2020
# 181320  Eleição Ordinária         426  Eleições Municipais 2020  15/11/2020
#
#        SG_UF  SG_UE          NM_UE  SQ_CANDIDATO  NR_ORDEM_CANDIDATO  \
# 92721     PE  23434     BOM JARDIM  170000801719                   8
# 810971    SP  63231      CATANDUVA  250000946323                   2
# 181320    BA  39748  MADRE DE DEUS   50001042622                   1
#
#         CD_TIPO_BEM_CANDIDATO  DS_TIPO_BEM_CANDIDATO  \
# 92721                      41  Caderneta de poupança
# 810971                     12                   Casa
# 181320                     12                   Casa
#
#                                          DS_BEM_CANDIDATO VR_BEM_CANDIDATO  \
# 92721   Saldo em conta poupança, conforme declaração d...        825000,00
# 810971                 IMOVEL RESIDENCIAL EM CATANDUVA-SP         45156,30
# 181320                             CASA 3/4 MADRE DE DEUS        350000,00
#
#        DT_ULTIMA_ATUALIZACAO HH_ULTIMA_ATUALIZACAO
# 92721             28/10/2020              17:39:43
# 810971            02/11/2020              17:38:18
# 181320            28/10/2020              17:31:40

# %%
list(df_receitas)
# Out:
# ['DT_GERACAO',
#  'HH_GERACAO',
#  'ANO_ELEICAO',
#  'CD_TIPO_ELEICAO',
#  'NM_TIPO_ELEICAO',
#  'CD_ELEICAO',
#  'DS_ELEICAO',
#  'DT_ELEICAO',
#  'ST_TURNO',
#  'TP_PRESTACAO_CONTAS',
#  'DT_PRESTACAO_CONTAS',
#  'SQ_PRESTADOR_CONTAS',
#  'SG_UF',
#  'SG_UE',
#  'NM_UE',
#  'NR_CNPJ_PRESTADOR_CONTA',
#  'CD_CARGO',
#  'DS_CARGO',
#  'SQ_CANDIDATO',
#  'NR_CANDIDATO',
#  'NM_CANDIDATO',
#  'NR_CPF_CANDIDATO',
#  'NR_CPF_VICE_CANDIDATO',
#  'NR_PARTIDO',
#  'SG_PARTIDO',
#  'NM_PARTIDO',
#  'CD_FONTE_RECEITA',
#  'DS_FONTE_RECEITA',
#  'CD_ORIGEM_RECEITA',
#  'DS_ORIGEM_RECEITA',
#  'CD_NATUREZA_RECEITA',
#  'DS_NATUREZA_RECEITA',
#  'CD_ESPECIE_RECEITA',
#  'DS_ESPECIE_RECEITA',
#  'CD_CNAE_DOADOR',
#  'DS_CNAE_DOADOR',
#  'NR_CPF_CNPJ_DOADOR',
#  'NM_DOADOR',
#  'NM_DOADOR_RFB',
#  'CD_ESFERA_PARTIDARIA_DOADOR',
#  'DS_ESFERA_PARTIDARIA_DOADOR',
#  'SG_UF_DOADOR',
#  'CD_MUNICIPIO_DOADOR',
#  'NM_MUNICIPIO_DOADOR',
#  'SQ_CANDIDATO_DOADOR',
#  'NR_CANDIDATO_DOADOR',
#  'CD_CARGO_CANDIDATO_DOADOR',
#  'DS_CARGO_CANDIDATO_DOADOR',
#  'NR_PARTIDO_DOADOR',
#  'SG_PARTIDO_DOADOR',
#  'NM_PARTIDO_DOADOR',
#  'NR_RECIBO_DOACAO',
#  'NR_DOCUMENTO_DOACAO',
#  'SQ_RECEITA',
#  'DT_RECEITA',
#  'DS_RECEITA',
#  'VR_RECEITA']

# %%
list(df_cadastro)
# Out:
# ['DT_GERACAO',
#  'HH_GERACAO',
#  'ANO_ELEICAO',
#  'CD_TIPO_ELEICAO',
#  'NM_TIPO_ELEICAO',
#  'NR_TURNO',
#  'CD_ELEICAO',
#  'DS_ELEICAO',
#  'DT_ELEICAO',
#  'TP_ABRANGENCIA',
#  'SG_UF',
#  'SG_UE',
#  'NM_UE',
#  'CD_CARGO',
#  'DS_CARGO',
#  'SQ_CANDIDATO',
#  'NR_CANDIDATO',
#  'NM_CANDIDATO',
#  'NM_URNA_CANDIDATO',
#  'NM_SOCIAL_CANDIDATO',
#  'NR_CPF_CANDIDATO',
#  'NM_EMAIL',
#  'CD_SITUACAO_CANDIDATURA',
#  'DS_SITUACAO_CANDIDATURA',
#  'CD_DETALHE_SITUACAO_CAND',
#  'DS_DETALHE_SITUACAO_CAND',
#  'TP_AGREMIACAO',
#  'NR_PARTIDO',
#  'SG_PARTIDO',
#  'NM_PARTIDO',
#  'SQ_COLIGACAO',
#  'NM_COLIGACAO',
#  'DS_COMPOSICAO_COLIGACAO',
#  'CD_NACIONALIDADE',
#  'DS_NACIONALIDADE',
#  'SG_UF_NASCIMENTO',
#  'CD_MUNICIPIO_NASCIMENTO',
#  'NM_MUNICIPIO_NASCIMENTO',
#  'DT_NASCIMENTO',
#  'NR_IDADE_DATA_POSSE',
#  'NR_TITULO_ELEITORAL_CANDIDATO',
#  'CD_GENERO',
#  'DS_GENERO',
#  'CD_GRAU_INSTRUCAO',
#  'DS_GRAU_INSTRUCAO',
#  'CD_ESTADO_CIVIL',
#  'DS_ESTADO_CIVIL',
#  'CD_COR_RACA',
#  'DS_COR_RACA',
#  'CD_OCUPACAO',
#  'DS_OCUPACAO',
#  'VR_DESPESA_MAX_CAMPANHA',
#  'CD_SIT_TOT_TURNO',
#  'DS_SIT_TOT_TURNO',
#  'ST_REELEICAO',
#  'ST_DECLARAR_BENS',
#  'NR_PROTOCOLO_CANDIDATURA',
#  'NR_PROCESSO',
#  'CD_SITUACAO_CANDIDATO_PLEITO',
#  'DS_SITUACAO_CANDIDATO_PLEITO',
#  'CD_SITUACAO_CANDIDATO_URNA',
#  'DS_SITUACAO_CANDIDATO_URNA',
#  'ST_CANDIDATO_INSERIDO_URNA']

# %%
list(df_bens)
# Out:
# ['DT_GERACAO',
#  'HH_GERACAO',
#  'ANO_ELEICAO',
#  'CD_TIPO_ELEICAO',
#  'NM_TIPO_ELEICAO',
#  'CD_ELEICAO',
#  'DS_ELEICAO',
#  'DT_ELEICAO',
#  'SG_UF',
#  'SG_UE',
#  'NM_UE',
#  'SQ_CANDIDATO',
#  'NR_ORDEM_CANDIDATO',
#  'CD_TIPO_BEM_CANDIDATO',
#  'DS_TIPO_BEM_CANDIDATO',
#  'DS_BEM_CANDIDATO',
#  'VR_BEM_CANDIDATO',
#  'DT_ULTIMA_ATUALIZACAO',
#  'HH_ULTIMA_ATUALIZACAO']

# %%
df_receitas['VR_RECEITA'] = df_receitas['VR_RECEITA'].apply(lambda x: float(x.replace(',', '.')))

# %%
df_receitas['NR_CPF_CANDIDATO'] = df_receitas['NR_CPF_CANDIDATO'].apply(lambda x: '0'*(11-len(str(x))) + str(x))

# %%
def corrige_cpf(x):
    if len(str(x)) < 11:
        y = '0'*(11-len(str(x))) + str(x)
    else:
        y = x
    return y

df_receitas['NR_CPF_CNPJ_DOADOR_'] = df_receitas['NR_CPF_CNPJ_DOADOR'].apply(corrige_cpf)

# %%
df_receitas[df_receitas['DS_FONTE_RECEITA'] == 'Fundo Especial'][['NM_CANDIDATO', 'DS_CARGO', 'VR_RECEITA']].groupby(['NM_CANDIDATO', 'DS_CARGO']).sum().reset_index().sort_values('VR_RECEITA', ascending = 0).head(5)
# Out:
#                                NM_CANDIDATO  DS_CARGO  VR_RECEITA
# 11993                     BRUNO COVAS LOPES  Prefeito  10952040.0
# 12163                     BRUNO SOARES REIS  Prefeito   8271750.0
# 42195  JOAO HENRIQUE DE ANDRADE LIMA CAMPOS  Prefeito   7500000.0
# 4362          ALFREDO PEREIRA DO NASCIMENTO  Prefeito   6000000.0
# 43039             JOICE CRISTINA HASSELMANN  Prefeito   5900000.0

# %%
df_receitas[['DS_FONTE_RECEITA', 'VR_RECEITA']].groupby(['DS_FONTE_RECEITA']).sum()
# Out:
#                     VR_RECEITA
# DS_FONTE_RECEITA
# Fundo Especial    1.287033e+09
# Fundo Partidario  5.813391e+07
# Outros Recursos   9.413488e+08

# %%
df_bens['VR_BEM_CANDIDATO'] = df_bens['VR_BEM_CANDIDATO'].apply(lambda x: float(x.replace(',','.')))

# %%
df_bens_agregado = df_bens[['SQ_CANDIDATO', 'VR_BEM_CANDIDATO']].groupby(['SQ_CANDIDATO']).sum().reset_index()

# %%
df_bens_agregado.sample(3)
# Out:
#         SQ_CANDIDATO  VR_BEM_CANDIDATO
# 243054  210000883078          172000.0
# 111396  130000837109            4000.0
# 259380  240000726240          593672.8

# %%
def faixa_bens(x):
    if x < 1000:
        y = '1. Menos do que R$ 1000'
    elif x < 10000:
        y = '2. Menos do que R$ 10.000,00'
    elif x < 100000:
        y = '3. Menos do que R$ 100.000,00'
    elif x < 1000000:
        y = '4. Menos do que R$ 1.000.000,00'
    else:
        y = '5. Mais do que 1.000.000,00'
    return y

df_bens_agregado['faixa_bens'] = df_bens_agregado['VR_BEM_CANDIDATO'].map(faixa_bens)

# %% [markdown]
# ### 2. Criando tabela juntando tudo: candidatos + receitas + variáveis demográficas (pivoteando fonte da receita)

# %%
df_receitas.sample(3)
# Out:
#         DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO NM_TIPO_ELEICAO  \
# 20395   06/11/2020   22:14:51         2020                2       Ordinária
# 443930  06/11/2020   22:14:51         2020                2       Ordinária
# 720359  06/11/2020   22:14:51         2020                2       Ordinária
#
#         CD_ELEICAO                DS_ELEICAO  DT_ELEICAO  ST_TURNO  \
# 20395          426  Eleições Municipais 2020  15/11/2020         1
# 443930         426  Eleições Municipais 2020  15/11/2020         1
# 720359         426  Eleições Municipais 2020  15/11/2020         1
#
#          TP_PRESTACAO_CONTAS         ...          NR_PARTIDO_DOADOR  \
# 20395   Relatório Financeiro         ...                         70
# 443930  Relatório Financeiro         ...                         55
# 720359  Relatório Financeiro         ...                         -1
#
#         SG_PARTIDO_DOADOR           NM_PARTIDO_DOADOR       NR_RECIBO_DOACAO  \
# 20395              AVANTE                      AVANTE                 #NULO#
# 443930                PSD  Partido Social Democrático  101711375132PR000001E
# 720359             #NULO#                      #NULO#  000551133804BA000002E
#
#        NR_DOCUMENTO_DOACAO  SQ_RECEITA  DT_RECEITA  \
# 20395            102813509    14078715  23/10/2020
# 443930              #NULO#    14636175  02/10/2020
# 720359              #NULO#    14510311  06/10/2020
#
#                                                DS_RECEITA  VR_RECEITA  \
# 20395                                              #NULO#       850.0
# 443930                                           GASOLINA        60.0
# 720359  CESSAO DE PONTO COMERCIAL PARA FUNCIONAMENTO D...       650.0
#
#         NR_CPF_CNPJ_DOADOR_
# 20395           03013381400
# 443930       38466848000183
# 720359          03313972500
#
# [3 rows x 58 columns]

# %%
df_demografia = df_receitas[df_receitas['DS_CARGO'] == 'Vereador'][['SQ_CANDIDATO', 'NR_CPF_CANDIDATO', 'NM_CANDIDATO', 'DS_CARGO', 'SG_PARTIDO', 'NM_UE', 'SG_UF']].drop_duplicates()\
               .merge(df_receitas[df_receitas['DS_FONTE_RECEITA'] == 'Fundo Especial'][['SQ_CANDIDATO', 'VR_RECEITA']].groupby(['SQ_CANDIDATO']).sum().reset_index(), how = 'left', on = 'SQ_CANDIDATO').fillna(0)\
               .merge(df_receitas[df_receitas['DS_FONTE_RECEITA'] == 'Fundo Partidario'][['SQ_CANDIDATO', 'VR_RECEITA']].groupby(['SQ_CANDIDATO']).sum().reset_index(), how = 'left', on = 'SQ_CANDIDATO').fillna(0)\
               .merge(df_receitas[df_receitas['DS_FONTE_RECEITA'] == 'Outros Recursos'][['SQ_CANDIDATO', 'VR_RECEITA']].groupby(['SQ_CANDIDATO']).sum().reset_index(), how = 'left', on = 'SQ_CANDIDATO').fillna(0)

df_demografia.columns = ['SQ_CANDIDATO', 'NR_CPF_CANDIDATO', 'NM_CANDIDATO', 'DS_CARGO', 'SG_PARTIDO', 'NM_UE', 'SG_UF', 'vl_fundo_especial', 'vl_fundo_partidario', 'vl_outros']
df_demografia['total_fundos_publicos'] = df_demografia['vl_fundo_especial'] + df_demografia['vl_fundo_partidario']
print(len(df_demografia))
# Out:
# 278629

# %%
df_demografia = df_demografia.merge(df_cadastro[['SQ_CANDIDATO', 'ST_REELEICAO', 'DS_COR_RACA', 'DS_GENERO', 'DS_GRAU_INSTRUCAO']], how = 'inner', on = 'SQ_CANDIDATO')\
                             .merge(df_bens_agregado, how = 'left', on = 'SQ_CANDIDATO').fillna({'VR_BEM_CANDIDATO': 0, 'faixa_bens': '1. Menos do que R$ 1000'})

# %%
df_demografia
# Out:
#         SQ_CANDIDATO NR_CPF_CANDIDATO  \
# 0       250000633489      22120219842
# 1       200000654036      87502119434
# 2       170000642379      84292458391
# 3       190000646259      41909453749
# 4       210000641601      68847300053
# 5        60000672038      05759338366
# 6        50000668095      02234371589
# 7       210000666516      02187044025
# 8        60000672037      25842552353
# 9       250000673480      36286121870
# 10      160000682798      88431711949
# 11      190000683667      59812249753
# 12      250000686862      31641391871
# 13      250000685996      26045677846
# 14      250000686007      26998967802
# 15      130000686222      03701141673
# 16      130000686197      90234723653
# 17      130000686198      08620238663
# 18      130000686218      75251884672
# 19      250000687515      36918558811
# 20      250000688237      43434914803
# 21      130000704275      04111815642
# 22      130000704150      62148265687
# 23      250000707382      02059822475
# 24      250000707384      29188906850
# 25       50000706617      03255079535
# 26       60000718115      21858535387
# 27      180000718489      78881099349
# 28       60000718106      02629462382
# 29       60000735247      81952716500
# ...              ...              ...
# 278599  230001248888      38225492234
# 278600  230001248880      94082260200
# 278601  230001248884      64862399215
# 278602  230001248886      80546811272
# 278603  180001238893      82992703320
# 278604  180001238894      00854325395
# 278605  170001260227      71521755434
# 278606  170001260251      08303685406
# 278607  170001260252      08950155443
# 278608  170001260219      06422448473
# 278609  170001260222      10439194490
# 278610  170001260235      43946763472
# 278611  170001260242      71505385415
# 278612  170001260238      04718455405
# 278613  170001260243      48715115453
# 278614  170001260232      48774510487
# 278615  250000972818      40305580892
# 278616  150000979704      10439162459
# 278617   50000672413      16523733572
# 278618  130000804515      81980825653
# 278619  240000833015      09674747958
# 278620  200000842387      75042150404
# 278621  270000995082      73278548191
# 278622  250001089639      48804231904
# 278623  250001089652      16185663856
# 278624  250001156600      00735902909
# 278625  130001176475      07864820603
# 278626  250001192025      06883768866
# 278627  250001230606      03890966870
# 278628  130001263836      37228447620
#
#                                       NM_CANDIDATO  DS_CARGO    SG_PARTIDO  \
# 0                              GUSTAVO LEMOS PETTA  Vereador       PC do B
# 1       GLACIA MARILLAC AZEVEDO DE MEDEIROS RONDON  Vereador          PODE
# 2                        CICERA JOSEFA DE CARVALHO  Vereador        AVANTE
# 3                          DILSON DE ARAUJO VIEIRA  Vereador          PSDB
# 4                      CRISTIANO DA COSTA SILVEIRA  Vereador  REPUBLICANOS
# 5                  FRANCISCA FABIANA ALVES PEREIRA  Vereador            PT
# 6                             DAVI CERQUEIRA GRILO  Vereador           PDT
# 7                     JAILSON DA ROCHA KATH JUNIOR  Vereador           MDB
# 8                          SERGIO BARBOSA DE PAULA  Vereador            PT
# 9                             CINTHYA GIANINI LINS  Vereador  REPUBLICANOS
# 10                        CLAUDENIR ANDRIANI PIRES  Vereador        AVANTE
# 11                           CARLOS AUGUSTO FELIPE  Vereador          PODE
# 12                         ELAINE CRISTINA MINEIRO  Vereador          PSOL
# 13                      SILVANIDIA PEREIRA SAMPAIO  Vereador            DC
# 14                        GLEIDSON ELOY DOS SANTOS  Vereador            DC
# 15                     POLLYANA DO AMARAL FERREIRA  Vereador          PSOL
# 16                        CASSIA CRISTINA DA SILVA  Vereador          PSOL
# 17                      ISABELLA GONÇALVES MIRANDA  Vereador          PSOL
# 18                      KENIA MÁRCIA ALVES RIBEIRO  Vereador          PSOL
# 19                             CARINA VITRAL COSTA  Vereador       PC do B
# 20                            WAFA AHMED EL KADIRI  Vereador          NOVO
# 21                        JULIANO CALDAS PARENTONI  Vereador      PATRIOTA
# 22                                    SONIA LANSKY  Vereador            PT
# 23              JOSÉ LUIZ BALBINO DOS SANTOS FILHO  Vereador          PRTB
# 24                    WAGNER JOSÉ CHIOVETTO ORSONI  Vereador          PRTB
# 25                           MARYELLE SOUZA LADEIA  Vereador           PSC
# 26                          ANTONIA NASCELIA SILVA  Vereador          PSOL
# 27                           THAIS BRAGLIA DA MOTA  Vereador            PL
# 28                          GABRIEL LIMA DE AGUIAR  Vereador          PSOL
# 29                        TAÍS ALVES DE LIMA MATOS  Vereador       PC do B
# ...                                            ...       ...           ...
# 278599                   RODOLPHO PEREIRA REBOUÇAS  Vereador           PMN
# 278600                  ARTENUSIA GOMES DOS SANTOS  Vereador           PMN
# 278601                 KELSEN RIVERA QUADROS PERES  Vereador           PMN
# 278602                   MARIA ISABEL SILVA SANTOS  Vereador           PMN
# 278603                  NAJRA JULITE MOREIRA NUNES  Vereador           PMN
# 278604              RAVENNA DE CASTRO LIMA AZEVEDO  Vereador           PMN
# 278605                CARLOS VINICIO GUEDES JUNIOR  Vereador           PMN
# 278606                         GILVAN JOSÉ CORREIA  Vereador           PMN
# 278607  GISDEISY GETICA CONCEIÇÃO MARQUES DA SILVA  Vereador           PMN
# 278608            AMANDA MARIA QUEIROZ DE OLIVEIRA  Vereador           PMN
# 278609                    CAMILA INGRID DOS SANTOS  Vereador           PMN
# 278610                       EDILZA ALVES DE SOUZA  Vereador           PMN
# 278611                  FÁBIO ROGÉRIO BORGES ALVES  Vereador           PMN
# 278612                         EDNA TEOTONIO SILVA  Vereador           PMN
# 278613         FERNANDO ANTÔNIO BEZERRA CAVALCANTI  Vereador           PMN
# 278614                   DALVA MARIA DE MELO SILVA  Vereador           PMN
# 278615                  LUCAS SANTOS DO NASCIMENTO  Vereador            UP
# 278616                 VITORIA OHARA MEIRELES DIAS  Vereador            UP
# 278617                 EUVALDO CARDOSO MELLO FILHO  Vereador           PSL
# 278618        RAISSA CRISTINA DE ALMEIDA SANTAROSA  Vereador      PATRIOTA
# 278619                   JONATAN BARDINI DOS ANJOS  Vereador          PSDB
# 278620                     RUTH BEZERRA DOS SANTOS  Vereador     CIDADANIA
# 278621                ANTONIA ANDREIA SEREJO SOUSA  Vereador           PTB
# 278622                     ANTONIO APARECIDO NUNES  Vereador          PODE
# 278623                 ELIANDRO JOSE DO NASCIMENTO  Vereador          PODE
# 278624                               ROBERTA STOPA  Vereador            PT
# 278625                 DANIEL FERNANDES FIGUEIREDO  Vereador           PTB
# 278626              CLAUDETE APARECIDA DE OLIVEIRA  Vereador          PSDB
# 278627                          LUIZ CARLOS SOARES  Vereador           MDB
# 278628            ANDREA MOREIRA ARANTES DE CASTRO  Vereador           PDT
#
#                           NM_UE SG_UF  vl_fundo_especial  vl_fundo_partidario  \
# 0                      CAMPINAS    SP           23483.42                  0.0
# 1                         NATAL    RN               0.00                  0.0
# 2                    SANTA CRUZ    PE               0.00                  0.0
# 3         CAMPOS DOS GOYTACAZES    RJ               0.00                  0.0
# 4                      ALVORADA    RS             423.80                  0.0
# 5                      ITAIÇABA    CE               0.00                  0.0
# 6              AMÉLIA RODRIGUES    BA               0.00                  0.0
# 7                       CAMAQUÃ    RS               0.00                  0.0
# 8                      ITAIÇABA    CE               0.00                  0.0
# 9               TABOÃO DA SERRA    SP               0.00                  0.0
# 10                      MARINGÁ    PR               0.00                  0.0
# 11                    CABO FRIO    RJ               0.00                  0.0
# 12                    SÃO PAULO    SP           45084.76                  0.0
# 13              TABOÃO DA SERRA    SP               0.00                  0.0
# 14              TABOÃO DA SERRA    SP               0.00                  0.0
# 15               BELO HORIZONTE    MG           21842.58                  0.0
# 16               BELO HORIZONTE    MG           54796.10                  0.0
# 17               BELO HORIZONTE    MG           78179.56                  0.0
# 18               BELO HORIZONTE    MG           13664.62                  0.0
# 19                    SÃO PAULO    SP           45455.35              50000.0
# 20                    SÃO PAULO    SP               0.00                  0.0
# 21               BELO HORIZONTE    MG               0.00                  0.0
# 22               BELO HORIZONTE    MG            3246.80                  0.0
# 23                  CARAPICUÍBA    SP               0.00                  0.0
# 24                  CARAPICUÍBA    SP               0.00                  0.0
# 25                   ITAPETINGA    BA               0.00                  0.0
# 26                    FORTALEZA    CE           39735.45                  0.0
# 27                     FLORIANO    PI               0.00                  0.0
# 28                    FORTALEZA    CE            4194.48                  0.0
# 29                    MARACANAÚ    CE            1989.62                  0.0
# ...                         ...   ...                ...                  ...
# 278599                BOA VISTA    RR            5960.00                  0.0
# 278600                BOA VISTA    RR            5960.00                  0.0
# 278601                BOA VISTA    RR            5960.00                  0.0
# 278602                BOA VISTA    RR            5960.00                  0.0
# 278603                 TERESINA    PI           20000.00                  0.0
# 278604                 TERESINA    PI          100000.00                  0.0
# 278605  JABOATÃO DOS GUARARAPES    PE               0.00                220.0
# 278606  JABOATÃO DOS GUARARAPES    PE               0.00                220.0
# 278607  JABOATÃO DOS GUARARAPES    PE               0.00                440.0
# 278608  JABOATÃO DOS GUARARAPES    PE               0.00                440.0
# 278609  JABOATÃO DOS GUARARAPES    PE               0.00                440.0
# 278610  JABOATÃO DOS GUARARAPES    PE               0.00                660.0
# 278611  JABOATÃO DOS GUARARAPES    PE               0.00                220.0
# 278612  JABOATÃO DOS GUARARAPES    PE               0.00                220.0
# 278613  JABOATÃO DOS GUARARAPES    PE               0.00                220.0
# 278614  JABOATÃO DOS GUARARAPES    PE               0.00                220.0
# 278615                SÃO PAULO    SP            2000.00                  0.0
# 278616              JOÃO PESSOA    PB            1000.00                  0.0
# 278617               JAGUAQUARA    BA               0.00                  0.0
# 278618           ANTÔNIO CARLOS    MG               0.00                  0.0
# 278619                BOMBINHAS    SC               0.00                  0.0
# 278620                  MOSSORÓ    RN               0.00                  0.0
# 278621              PALMEIRANTE    TO               0.00                  0.0
# 278622      SANTANA DE PARNAÍBA    SP               0.00                  0.0
# 278623      SANTANA DE PARNAÍBA    SP               0.00                  0.0
# 278624                 OURINHOS    SP               0.00                  0.0
# 278625                NOVA LIMA    MG               0.00                  0.0
# 278626              PINHALZINHO    SP               0.00                  0.0
# 278627     PRESIDENTE VENCESLAU    SP               0.00                  0.0
# 278628                NOVA LIMA    MG               0.00                  0.0
#
#         vl_outros  total_fundos_publicos ST_REELEICAO DS_COR_RACA  DS_GENERO  \
# 0         6780.30               23483.42            N      BRANCA  MASCULINO
# 1        12940.00                   0.00            N       PARDA   FEMININO
# 2         4488.00                   0.00            N       PARDA   FEMININO
# 3         1300.00                   0.00            N       PARDA  MASCULINO
# 4          440.00                 423.80            N      BRANCA  MASCULINO
# 5          520.00                   0.00            N       PARDA   FEMININO
# 6          700.00                   0.00            N       PARDA  MASCULINO
# 7          465.00                   0.00            N      BRANCA  MASCULINO
# 8         4370.00                   0.00            N       PRETA  MASCULINO
# 9         2624.00                   0.00            N      BRANCA   FEMININO
# 10        6741.46                   0.00            N      BRANCA  MASCULINO
# 11        6500.00                   0.00            N      BRANCA  MASCULINO
# 12      145172.00               45084.76            N       PRETA   FEMININO
# 13        1950.00                   0.00            N      BRANCA   FEMININO
# 14       20000.00                   0.00            N       PARDA  MASCULINO
# 15        5031.13               21842.58            N      BRANCA   FEMININO
# 16         730.00               54796.10            N       PRETA   FEMININO
# 17       51305.26               78179.56            N      BRANCA   FEMININO
# 18       11290.00               13664.62            N       PRETA   FEMININO
# 19       69095.00               95455.35            N      BRANCA   FEMININO
# 20      144160.25                   0.00            N      BRANCA   FEMININO
# 21        4990.00                   0.00            N       PARDA  MASCULINO
# 22       55784.51                3246.80            N      BRANCA   FEMININO
# 23         550.00                   0.00            N       PARDA  MASCULINO
# 24         550.00                   0.00            N      BRANCA  MASCULINO
# 25         460.87                   0.00            N       PARDA   FEMININO
# 26        9600.00               39735.45            N      BRANCA   FEMININO
# 27        2000.00                   0.00            N      BRANCA   FEMININO
# 28       29393.00                4194.48            N      BRANCA  MASCULINO
# 29       12450.00                1989.62            N       PRETA   FEMININO
# ...           ...                    ...          ...         ...        ...
# 278599       0.00                5960.00            N       PARDA  MASCULINO
# 278600       0.00                5960.00            N      BRANCA   FEMININO
# 278601       0.00                5960.00            N      BRANCA  MASCULINO
# 278602       0.00                5960.00            N       PRETA   FEMININO
# 278603       0.00               20000.00            N      BRANCA   FEMININO
# 278604       0.00              100000.00            N      BRANCA   FEMININO
# 278605       0.00                 220.00            N      BRANCA  MASCULINO
# 278606       0.00                 220.00            N       PARDA  MASCULINO
# 278607       0.00                 440.00            N      BRANCA   FEMININO
# 278608       0.00                 440.00            N       PARDA   FEMININO
# 278609       0.00                 440.00            N      BRANCA   FEMININO
# 278610       0.00                 660.00            N       PARDA   FEMININO
# 278611       0.00                 220.00            N      BRANCA  MASCULINO
# 278612       0.00                 220.00            N       PARDA   FEMININO
# 278613       0.00                 220.00            N       PARDA  MASCULINO
# 278614       0.00                 220.00            N      BRANCA   FEMININO
# 278615       0.00                2000.00            N       PRETA  MASCULINO
# 278616       0.00                1000.00            N       PARDA   FEMININO
# 278617    1200.00                   0.00            N      BRANCA  MASCULINO
# 278618     430.00                   0.00            N      BRANCA   FEMININO
# 278619     550.00                   0.00            N      BRANCA  MASCULINO
# 278620     200.00                   0.00            N      BRANCA   FEMININO
# 278621     150.00                   0.00            N       PARDA   FEMININO
# 278622     700.00                   0.00            S      BRANCA  MASCULINO
# 278623    1000.00                   0.00            N       PARDA  MASCULINO
# 278624    4970.00                   0.00            N      BRANCA   FEMININO
# 278625     455.05                   0.00            N      BRANCA  MASCULINO
# 278626     272.58                   0.00            N      BRANCA   FEMININO
# 278627     950.00                   0.00            N      BRANCA  MASCULINO
# 278628     324.00                   0.00            N      BRANCA   FEMININO
#
#                     DS_GRAU_INSTRUCAO  VR_BEM_CANDIDATO  \
# 0                 SUPERIOR INCOMPLETO         144692.29
# 1                   SUPERIOR COMPLETO         438000.00
# 2               ENSINO MÉDIO COMPLETO         140000.00
# 3             ENSINO MÉDIO INCOMPLETO              0.00
# 4               ENSINO MÉDIO COMPLETO         235000.00
# 5                 SUPERIOR INCOMPLETO              0.00
# 6                   SUPERIOR COMPLETO         276000.00
# 7               ENSINO MÉDIO COMPLETO              0.00
# 8                   SUPERIOR COMPLETO              0.00
# 9       ENSINO FUNDAMENTAL INCOMPLETO              0.00
# 10              ENSINO MÉDIO COMPLETO          42575.60
# 11        ENSINO FUNDAMENTAL COMPLETO         199333.33
# 12              ENSINO MÉDIO COMPLETO              0.00
# 13                  SUPERIOR COMPLETO           9000.00
# 14                  SUPERIOR COMPLETO        1614050.00
# 15                  SUPERIOR COMPLETO         246216.54
# 16      ENSINO FUNDAMENTAL INCOMPLETO           7000.00
# 17                  SUPERIOR COMPLETO          82316.31
# 18              ENSINO MÉDIO COMPLETO           8000.00
# 19                SUPERIOR INCOMPLETO              0.00
# 20                SUPERIOR INCOMPLETO              0.00
# 21              ENSINO MÉDIO COMPLETO         321800.00
# 22                  SUPERIOR COMPLETO        1229808.00
# 23              ENSINO MÉDIO COMPLETO              0.00
# 24                SUPERIOR INCOMPLETO           1090.05
# 25              ENSINO MÉDIO COMPLETO          22000.00
# 26                  SUPERIOR COMPLETO         500000.00
# 27                  SUPERIOR COMPLETO          41000.00
# 28                  SUPERIOR COMPLETO         181750.00
# 29                  SUPERIOR COMPLETO          30000.00
# ...                               ...               ...
# 278599            SUPERIOR INCOMPLETO              0.00
# 278600          ENSINO MÉDIO COMPLETO              0.00
# 278601              SUPERIOR COMPLETO          11000.00
# 278602            SUPERIOR INCOMPLETO          80000.00
# 278603              SUPERIOR COMPLETO         794660.12
# 278604              SUPERIOR COMPLETO          90019.07
# 278605          ENSINO MÉDIO COMPLETO              0.00
# 278606          ENSINO MÉDIO COMPLETO              0.00
# 278607              SUPERIOR COMPLETO              0.00
# 278608              SUPERIOR COMPLETO              0.00
# 278609          ENSINO MÉDIO COMPLETO              0.00
# 278610    ENSINO FUNDAMENTAL COMPLETO              0.00
# 278611            SUPERIOR INCOMPLETO         144000.00
# 278612    ENSINO FUNDAMENTAL COMPLETO              0.00
# 278613            SUPERIOR INCOMPLETO              0.00
# 278614          ENSINO MÉDIO COMPLETO              0.00
# 278615            SUPERIOR INCOMPLETO              0.00
# 278616          ENSINO MÉDIO COMPLETO              0.00
# 278617              SUPERIOR COMPLETO          86549.31
# 278618              SUPERIOR COMPLETO              0.00
# 278619              SUPERIOR COMPLETO          61856.41
# 278620          ENSINO MÉDIO COMPLETO          30000.00
# 278621        ENSINO MÉDIO INCOMPLETO              0.00
# 278622  ENSINO FUNDAMENTAL INCOMPLETO            500.00
# 278623          ENSINO MÉDIO COMPLETO            450.00
# 278624              SUPERIOR COMPLETO          36069.22
# 278625            SUPERIOR INCOMPLETO              0.00
# 278626          ENSINO MÉDIO COMPLETO              0.00
# 278627          ENSINO MÉDIO COMPLETO              0.00
# 278628              SUPERIOR COMPLETO         695000.00
#
#                              faixa_bens
# 0       4. Menos do que R$ 1.000.000,00
# 1       4. Menos do que R$ 1.000.000,00
# 2       4. Menos do que R$ 1.000.000,00
# 3               1. Menos do que R$ 1000
# 4       4. Menos do que R$ 1.000.000,00
# 5               1. Menos do que R$ 1000
# 6       4. Menos do que R$ 1.000.000,00
# 7               1. Menos do que R$ 1000
# 8               1. Menos do que R$ 1000
# 9               1. Menos do que R$ 1000
# 10        3. Menos do que R$ 100.000,00
# 11      4. Menos do que R$ 1.000.000,00
# 12              1. Menos do que R$ 1000
# 13         2. Menos do que R$ 10.000,00
# 14          5. Mais do que 1.000.000,00
# 15      4. Menos do que R$ 1.000.000,00
# 16         2. Menos do que R$ 10.000,00
# 17        3. Menos do que R$ 100.000,00
# 18         2. Menos do que R$ 10.000,00
# 19              1. Menos do que R$ 1000
# 20              1. Menos do que R$ 1000
# 21      4. Menos do que R$ 1.000.000,00
# 22          5. Mais do que 1.000.000,00
# 23              1. Menos do que R$ 1000
# 24         2. Menos do que R$ 10.000,00
# 25        3. Menos do que R$ 100.000,00
# 26      4. Menos do que R$ 1.000.000,00
# 27        3. Menos do que R$ 100.000,00
# 28      4. Menos do que R$ 1.000.000,00
# 29        3. Menos do que R$ 100.000,00
# ...                                 ...
# 278599          1. Menos do que R$ 1000
# 278600          1. Menos do que R$ 1000
# 278601    3. Menos do que R$ 100.000,00
# 278602    3. Menos do que R$ 100.000,00
# 278603  4. Menos do que R$ 1.000.000,00
# 278604    3. Menos do que R$ 100.000,00
# 278605          1. Menos do que R$ 1000
# 278606          1. Menos do que R$ 1000
# 278607          1. Menos do que R$ 1000
# 278608          1. Menos do que R$ 1000
# 278609          1. Menos do que R$ 1000
# 278610          1. Menos do que R$ 1000
# 278611  4. Menos do que R$ 1.000.000,00
# 278612          1. Menos do que R$ 1000
# 278613          1. Menos do que R$ 1000
# 278614          1. Menos do que R$ 1000
# 278615          1. Menos do que R$ 1000
# 278616          1. Menos do que R$ 1000
# 278617    3. Menos do que R$ 100.000,00
# 278618          1. Menos do que R$ 1000
# 278619    3. Menos do que R$ 100.000,00
# 278620    3. Menos do que R$ 100.000,00
# 278621          1. Menos do que R$ 1000
# 278622          1. Menos do que R$ 1000
# 278623          1. Menos do que R$ 1000
# 278624    3. Menos do que R$ 100.000,00
# 278625          1. Menos do que R$ 1000
# 278626          1. Menos do que R$ 1000
# 278627          1. Menos do que R$ 1000
# 278628  4. Menos do que R$ 1.000.000,00
#
# [278629 rows x 17 columns]

# %% [markdown]
# ##### -> Distribuições por raça, gênero, instrução e faixa de bens

# %%
## Raça
df_demografia[['DS_COR_RACA', 'vl_fundo_especial']].groupby(['DS_COR_RACA']).mean()
# Out:
#                 vl_fundo_especial
# DS_COR_RACA
# AMARELA               2163.930373
# BRANCA                1151.060753
# INDÍGENA              2180.137740
# PARDA                 1450.840361
# PRETA                 1962.214955
# SEM INFORMAÇÃO         613.581282

# %%
df_demografia[['DS_COR_RACA', 'vl_fundo_especial']].groupby(['DS_COR_RACA']).mean()['vl_fundo_especial'][4]/\
df_demografia[['DS_COR_RACA', 'vl_fundo_especial']].groupby(['DS_COR_RACA']).mean()['vl_fundo_especial'][1]
# Out:
# 1.7047014686614625

# %%
import seaborn as sns
from matplotlib.pyplot import figure
figure(num=None, figsize=(18, 6), dpi=80, facecolor='w', edgecolor='k')

sns.set(style='darkgrid')
sns.set_palette("rocket")
sns.set(font_scale = 1.4)
dados = df_demografia[['DS_COR_RACA', 'vl_fundo_especial']].groupby(['DS_COR_RACA']).mean().reset_index()
dados.columns = ['Raça declarada pelo candidato', 'Valor Médio Recebido']
ax = sns.barplot(x= 'Raça declarada pelo candidato', y= 'Valor Médio Recebido', data=dados)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')
# Out:
# [Text(0, 0, 'AMARELA'),
#  Text(0, 0, 'BRANCA'),
#  Text(0, 0, 'INDÍGENA'),
#  Text(0, 0, 'PARDA'),
#  Text(0, 0, 'PRETA'),
#  Text(0, 0, 'SEM INFORMAÇÃO')]

# %%
## Gênero
df_demografia[['DS_GENERO', 'vl_fundo_especial']].groupby(['DS_GENERO']).mean()
# Out:
#            vl_fundo_especial
# DS_GENERO
# FEMININO         1719.204121
# MASCULINO        1163.512897

# %%
df_demografia[['DS_GENERO', 'vl_fundo_especial']].groupby(['DS_GENERO']).mean()['vl_fundo_especial'][0]/\
df_demografia[['DS_GENERO', 'vl_fundo_especial']].groupby(['DS_GENERO']).mean()['vl_fundo_especial'][1]
# Out:
# 1.47759782149201

# %%
import seaborn as sns
from matplotlib.pyplot import figure
figure(num=None, figsize=(18, 6), dpi=80, facecolor='w', edgecolor='k')

sns.set(style='darkgrid')
sns.set_palette("rocket")
sns.set(font_scale = 1.4)
dados = df_demografia[['DS_GENERO', 'vl_fundo_especial']].groupby(['DS_GENERO']).mean().reset_index()
dados.columns = ['Gênero declarado', 'Valor Médio Recebido']
ax = sns.barplot(x= 'Gênero declarado', y= 'Valor Médio Recebido', data=dados)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')
# Out:
# [Text(0, 0, 'FEMININO'), Text(0, 0, 'MASCULINO')]

# %%
## DS_GRAU_INSTRUCAO
df_demografia[['DS_GRAU_INSTRUCAO', 'vl_fundo_especial']].groupby(['DS_GRAU_INSTRUCAO']).mean()
# Out:
#                                vl_fundo_especial
# DS_GRAU_INSTRUCAO
# ANALFABETO                              0.000000
# ENSINO FUNDAMENTAL COMPLETO           680.694868
# ENSINO FUNDAMENTAL INCOMPLETO         591.361789
# ENSINO MÉDIO COMPLETO                1092.942844
# ENSINO MÉDIO INCOMPLETO               850.888478
# LÊ E ESCREVE                          728.986656
# SUPERIOR COMPLETO                    2302.895957
# SUPERIOR INCOMPLETO                  2432.057357

# %%
import seaborn as sns
from matplotlib.pyplot import figure
figure(num=None, figsize=(18, 6), dpi=80, facecolor='w', edgecolor='k')

sns.set(style='darkgrid')
sns.set_palette("rocket")
sns.set(font_scale = 1.4)
dados = df_demografia[df_demografia['DS_GRAU_INSTRUCAO'] != 'ANALFABETO'][['DS_GRAU_INSTRUCAO', 'vl_fundo_especial']].groupby(['DS_GRAU_INSTRUCAO']).mean().reset_index()
dados.columns = ['Grau de Instrução', 'Valor Médio Recebido']
ax = sns.barplot(x= 'Grau de Instrução', y= 'Valor Médio Recebido', data=dados)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')
# Out:
# [Text(0, 0, 'ENSINO FUNDAMENTAL COMPLETO'),
#  Text(0, 0, 'ENSINO FUNDAMENTAL INCOMPLETO'),
#  Text(0, 0, 'ENSINO MÉDIO COMPLETO'),
#  Text(0, 0, 'ENSINO MÉDIO INCOMPLETO'),
#  Text(0, 0, 'LÊ E ESCREVE'),
#  Text(0, 0, 'SUPERIOR COMPLETO'),
#  Text(0, 0, 'SUPERIOR INCOMPLETO')]

# %%
## faixa_bens
df_demografia[['faixa_bens', 'vl_fundo_especial']].groupby(['faixa_bens']).mean()
# Out:
#                                  vl_fundo_especial
# faixa_bens
# 1. Menos do que R$ 1000                1425.337390
# 2. Menos do que R$ 10.000,00            852.480758
# 3. Menos do que R$ 100.000,00          1099.165700
# 4. Menos do que R$ 1.000.000,00        1410.018090
# 5. Mais do que 1.000.000,00            4171.255362

# %%
df_demografia[['faixa_bens', 'vl_fundo_especial']].groupby(['faixa_bens']).mean()['vl_fundo_especial'][-1]/\
df_demografia[['faixa_bens', 'vl_fundo_especial']].groupby(['faixa_bens']).mean()['vl_fundo_especial'][0]
# Out:
# 2.9265038511152794

# %%
import seaborn as sns
from matplotlib.pyplot import figure
figure(num=None, figsize=(18, 6), dpi=80, facecolor='w', edgecolor='k')

sns.set(style='darkgrid')
sns.set_palette("rocket")
sns.set(font_scale = 1.4)
dados = df_demografia[['faixa_bens', 'vl_fundo_especial']].groupby(['faixa_bens']).mean().reset_index()
dados.columns = ['Faixa de Patrimônio dos Candidatos', 'Valor Médio Recebido']
ax = sns.barplot(x="Faixa de Patrimônio dos Candidatos", y="Valor Médio Recebido", data=dados)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')
# Out:
# [Text(0, 0, '1. Menos do que R$ 1000'),
#  Text(0, 0, '2. Menos do que R$ 10.000,00'),
#  Text(0, 0, '3. Menos do que R$ 100.000,00'),
#  Text(0, 0, '4. Menos do que R$ 1.000.000,00'),
#  Text(0, 0, '5. Mais do que 1.000.000,00')]

# %%
# Calculando concentração na renda, incluindo prefeitos.
df_demografia_ = df_receitas[['SQ_CANDIDATO', 'NR_CPF_CANDIDATO', 'NM_CANDIDATO', 'DS_CARGO', 'SG_PARTIDO', 'NM_UE', 'SG_UF']].drop_duplicates()\
               .merge(df_receitas[df_receitas['DS_FONTE_RECEITA'] == 'Fundo Especial'][['SQ_CANDIDATO', 'VR_RECEITA']].groupby(['SQ_CANDIDATO']).sum().reset_index(), how = 'left', on = 'SQ_CANDIDATO').fillna(0)\
               .merge(df_receitas[df_receitas['DS_FONTE_RECEITA'] == 'Fundo Partidario'][['SQ_CANDIDATO', 'VR_RECEITA']].groupby(['SQ_CANDIDATO']).sum().reset_index(), how = 'left', on = 'SQ_CANDIDATO').fillna(0)\
               .merge(df_receitas[df_receitas['DS_FONTE_RECEITA'] == 'Outros Recursos'][['SQ_CANDIDATO', 'VR_RECEITA']].groupby(['SQ_CANDIDATO']).sum().reset_index(), how = 'left', on = 'SQ_CANDIDATO').fillna(0)

df_demografia_.columns = ['SQ_CANDIDATO', 'NR_CPF_CANDIDATO', 'NM_CANDIDATO', 'DS_CARGO', 'SG_PARTIDO', 'NM_UE', 'SG_UF', 'vl_fundo_especial', 'vl_fundo_partidario', 'vl_outros']
df_demografia_['total_fundos_publicos'] = df_demografia_['vl_fundo_especial'] + df_demografia_['vl_fundo_partidario']
print(len(df_demografia_))
# Out:
# 295329

# %%
df_demografia_ = df_demografia_.merge(df_cadastro[['SQ_CANDIDATO', 'ST_REELEICAO', 'DS_COR_RACA', 'DS_GENERO', 'DS_GRAU_INSTRUCAO']], how = 'inner', on = 'SQ_CANDIDATO')\
                             .merge(df_bens_agregado, how = 'left', on = 'SQ_CANDIDATO').fillna({'VR_BEM_CANDIDATO': 0, 'faixa_bens': '1. Menos do que R$ 1000'})

# %%
df_demografia_[['faixa_bens', 'vl_fundo_especial']].groupby(['faixa_bens']).mean()
# Out:
#                                  vl_fundo_especial
# faixa_bens
# 1. Menos do que R$ 1000                1946.273087
# 2. Menos do que R$ 10.000,00           1165.789468
# 3. Menos do que R$ 100.000,00          2244.243765
# 4. Menos do que R$ 1.000.000,00        6874.373811
# 5. Mais do que 1.000.000,00           30452.880321

# %%
df_demografia_[['faixa_bens', 'vl_fundo_especial']].groupby(['faixa_bens']).mean()['vl_fundo_especial'][-1]/\
df_demografia_[['faixa_bens', 'vl_fundo_especial']].groupby(['faixa_bens']).mean()['vl_fundo_especial'][0]
# Out:
# 15.646766390724535

# %% [markdown]
# ### 3. Calculando o indicador de concentração (por faixa de renda) por partido

# %%
lista_partidos = [k for k in list(set(df_demografia['SG_PARTIDO'])) if k != 'NOVO']
lista_indicadores = []

for partido in lista_partidos:

    df_temp = df_demografia[df_demografia['SG_PARTIDO'] == partido][['faixa_bens', 'vl_fundo_especial']].groupby(['faixa_bens']).mean()
    indicador = df_temp['vl_fundo_especial'][-1]/df_temp['vl_fundo_especial'][0]

    lista_indicadores.append(indicador)
    
    print(partido)
# Out:
# PMB
# PROS
# DEM
# PC do B
# PSOL
# DC
# SOLIDARIEDADE
# PSC
# PSB
# PDT
# PRTB
# PTB
# PTC
# PP
# CIDADANIA
# PV
# PMN
# PSD
# REPUBLICANOS
# REDE
# PCO
# PODE
# PCB
# PT
# PSL
# PSDB
# UP
# PSTU
# PL
# MDB
# PATRIOTA
# AVANTE

# %%
dict_ = {'Partido': lista_partidos, 'Fator_de_Concentração': lista_indicadores}  
    
df_fator_des = pd.DataFrame(dict_)

# %%
lista_principais = df_demografia[['SG_PARTIDO', 'vl_fundo_especial']].groupby('SG_PARTIDO').sum().reset_index()
lista_principais = lista_principais[lista_principais['vl_fundo_especial'] > 1000000]
lista_principais = list(lista_principais['SG_PARTIDO'])
lista_principais
# Out:
# ['AVANTE',
#  'CIDADANIA',
#  'DEM',
#  'MDB',
#  'PATRIOTA',
#  'PC do B',
#  'PDT',
#  'PL',
#  'PMN',
#  'PODE',
#  'PP',
#  'PROS',
#  'PSB',
#  'PSC',
#  'PSD',
#  'PSDB',
#  'PSL',
#  'PSOL',
#  'PT',
#  'PTB',
#  'PTC',
#  'PV',
#  'REDE',
#  'REPUBLICANOS',
#  'SOLIDARIEDADE']

# %%
def principal(x):
    if x in lista_principais:
        y = 1
    else:
        y = 0
    return y

# %%
df_fator_des['principal'] = df_fator_des['Partido'].map(principal)

# %%
df_fator_des[df_fator_des['principal'] == 1].sort_values('Fator_de_Concentração', ascending = 0)
# Out:
#           Partido  Fator_de_Concentração  principal
# 2             DEM              15.623719          1
# 12            PTC               9.294687          1
# 28             PL               5.921701          1
# 15             PV               4.732341          1
# 8             PSB               4.591034          1
# 4            PSOL               3.521888          1
# 16            PMN               3.430552          1
# 7             PSC               3.189696          1
# 21           PODE               3.089334          1
# 31         AVANTE               2.927847          1
# 1            PROS               2.874212          1
# 17            PSD               2.748438          1
# 6   SOLIDARIEDADE               2.706662          1
# 23             PT               2.593077          1
# 25           PSDB               2.328262          1
# 13             PP               2.132181          1
# 19           REDE               2.055723          1
# 14      CIDADANIA               1.880066          1
# 3         PC do B               1.771543          1
# 29            MDB               1.620549          1
# 30       PATRIOTA               1.555881          1
# 24            PSL               1.453552          1
# 18   REPUBLICANOS               1.403806          1
# 11            PTB               0.825632          1
# 9             PDT               0.589954          1

# %%
import seaborn as sns
from matplotlib.pyplot import figure
figure(num=None, figsize=(18, 6), dpi=80, facecolor='w', edgecolor='k')

sns.set(style='darkgrid')
sns.set_palette("rocket")
sns.set(font_scale = 1.2)
dados = df_fator_des[df_fator_des['principal'] == 1].sort_values('Fator_de_Concentração', ascending = 0)
ax = sns.barplot(x="Partido", y="Fator_de_Concentração", data=dados)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')
# Out:
# [Text(0, 0, 'DEM'),
#  Text(0, 0, 'PTC'),
#  Text(0, 0, 'PL'),
#  Text(0, 0, 'PV'),
#  Text(0, 0, 'PSB'),
#  Text(0, 0, 'PSOL'),
#  Text(0, 0, 'PMN'),
#  Text(0, 0, 'PSC'),
#  Text(0, 0, 'PODE'),
#  Text(0, 0, 'AVANTE'),
#  Text(0, 0, 'PROS'),
#  Text(0, 0, 'PSD'),
#  Text(0, 0, 'SOLIDARIEDADE'),
#  Text(0, 0, 'PT'),
#  Text(0, 0, 'PSDB'),
#  Text(0, 0, 'PP'),
#  Text(0, 0, 'REDE'),
#  Text(0, 0, 'CIDADANIA'),
#  Text(0, 0, 'PC do B'),
#  Text(0, 0, 'MDB'),
#  Text(0, 0, 'PATRIOTA'),
#  Text(0, 0, 'PSL'),
#  Text(0, 0, 'REPUBLICANOS'),
#  Text(0, 0, 'PTB'),
#  Text(0, 0, 'PDT')]
